# %%
import pandas as pd

# %%
# file = pd.read_csv("geojson_to_csv_updated.csv", quotechar="\'")
file = pd.read_csv("bengaluru_india_amenities_metrics.csv", quotechar="\'")

# %%
file
# Out:
#          Name                                        description  \
# 0      Ward 1  Ward Name: Kempegowda Ward<br>Zone: Yelahanka<...
# 1      Ward 4  Ward Name: Yelahanka Satellite Town<br>Zone: Y...
# 2      Ward 2  Ward Name: Chowdeswari Ward<br>Zone: Yelahanka...
# 3      Ward 3  Ward Name: Atturu<br>Zone: Yelahanka<br>Divisi...
# 4     Ward 30  Ward Name: Kadugondanahalli<br>Zone: East<br>D...
# 5      Ward 5  Ward Name: Jakkuru<br>Zone: Yelahanka<br>Divis...
# 6      Ward 8  Ward Name: Kodigehalli<br>Zone: Yelahanka<br>D...
# 7      Ward 6  Ward Name: Thanisandra<br>Zone: Yelahanka<br>D...
# 8      Ward 7  Ward Name: Byatarayanapura<br>Zone: Yelahanka<...
# 9     Ward 15  Ward Name: T Dasarahalli<br>Zone: Dasarahalli ...
# 10     Ward 9  Ward Name: Vidyaranyapura<br>Zone: Yelahanka<b...
# 11    Ward 16  Ward Name: Jalahalli<br>Zone: Rajarajeshwari N...
# 12    Ward 10  Ward Name: Dodda Bommasandra<br>Zone: Yelahank...
# ...

# %%
file['geo.coordinates']
# Out:
# 0      {"geometry": {"type": "Polygon", "coordinates"...
# 1      {"geometry": {"type": "Polygon", "coordinates"...
# 2      {"geometry": {"type": "Polygon", "coordinates"...
# 3      {"geometry": {"type": "Polygon", "coordinates"...
# 4      {"geometry": {"type": "Polygon", "coordinates"...
# 5      {"geometry": {"type": "Polygon", "coordinates"...
# 6      {"geometry": {"type": "Polygon", "coordinates"...
# 7      {"geometry": {"type": "Polygon", "coordinates"...
# 8      {"geometry": {"type": "Polygon", "coordinates"...
# 9      {"geometry": {"type": "Polygon", "coordinates"...
# 10     {"geometry": {"type": "Polygon", "coordinates"...
# 11     {"geometry": {"type": "Polygon", "coordinates"...
# 12     {"geometry": {"type": "Polygon", "coordinates"...
# 13     {"geometry": {"type": "Polygon", "coordinates"...
# 14     {"geometry": {"type": "Polygon", "coordinates"...
# 15     {"geometry": {"type": "Polygon", "coordinates"...
# ...

# %%
file.to_csv("new2.csv")
